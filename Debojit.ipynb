# %%
import qrcode

# %%
# import qrcode

qr = qrcode.make('Aditya Sir\n'
                "mobile: 9999999999\n"
                "address: Us ladki ke pichhe wali gali me")

qr.save('Chalo uski gali me.png')

print('QR Code generated successfully')
# Out:
# QR Code generated successfully
