# %% [markdown]
# Hostel Management System

# %%
out_alloted_ac_rooms = set()
out_alloted_non_ac_rooms = set()

inside_alloted_ac_rooms = set()
inside_alloted_non_ac_rooms = set()

roomCosting = {"AC Single" : 160000,
              "AC Double" : 140000,
              "NON-AC Single" : 120000,
              "NON-AC Double" : 110000,
              "NON-AC Triple" : 900000}

# %%
def print_ac_type_cost(room_dict):   
    found = False
    for room_type, cost in room_dict.items():
        if "AC" in room_type and not "NON-AC" in room_type:
            print(f"{room_type} : ₹{cost}")
            found = True
        # elif not found:
        #     print("No AC room found")
    print()

def print_non_ac_type_cost(room_dict):
    found = True
    for room_type, cost in room_dict.items():
        if "NON-AC" in room_type:
            print(f"{room_type} : ₹{cost}")
            found = False
        # elif found:
        #     print("No NON-AC room found")
    print()


def pay_ac_single_double(choose):
    if choose == "single":
        print("\nEnter your upi here: ", end=" ")
        upi = input()
        print()
        print("A payment link of ₹160000 has send to your number. \nPlease pay that amount immediatly befor expire of link\n")
        print("Thanks for the payment. Your room has been alloted\n")
    elif choose == "double":
        print("\nEnter your upi here: ", end=" ")
        upi = input()
        print()
        print("A payment link of ₹140000 has send to your number. \nPlease pay that amount immediatly befor expire of link\n")
        print("Thanks for the payment. Your room has been alloted\n")
    else:
        print("\nPlease enter a valid input!")


def pay_non_ac_single_double_triple(choose):
    if choose == "single":
        print("\nEnter your upi here: ", end=" ")
        upi = input("\n")
        print()
        print("A payment link of ₹120000 has send to your number. \nPlease pay that amount immediatly befor expire of link\n")
        print("Thanks for the payment. Your room has been alloted\n")
    elif choose == "double":
        print("\nEnter your upi here: ", end=" ")
        upi = input("\n")
        print()
        print("A payment link of ₹110000 has send to your number. \nPlease pay that amount immediatly befor expire of link\n")
        print("Thanks for the payment. Your room has been alloted\n")
    elif choose == "triple":
        print("\nEnter your upi here: ", end=" ")
        upi = input("\n")
        print()
        print("A payment link of ₹90000 has send to your number. \nPlease pay that amount immediatly befor expire of link\n")
        print("Thanks for the payment. Your room has been alloted\n")
    else:
        print("\nPlease enter a valid input!")



def AC_NONAC_selection_process(isAC):
    # AC
    if isAC=="ac":
        #printing the type and cost of ac rooms usign the function
        print("AC Room and Respective Cost\n")
        print(print_ac_type_cost(roomCosting))

        #payment gateway process
        choose = input("\nChoose Single or Double AC rooms ").lower().strip()
        if choose == "single" or choose == "double":
            #calling the payment fun for AC rooms
            pay_ac_single_double(choose)
          
        else:
            print("\nplease select a valid input")
        

    # NON-AC  
    elif isAC == "non-ac":
        #printing the type and cost of non-ac rooms using the function
        print(print_non_ac_type_cost(roomCosting)) 

        #payment gateway process
        choose = input("\nChoose Single or Double or Triple NON-AC rooms ").lower().strip()
        if choose == "single" or choose == "double" or choose =="triple":
            #calling the payment fun for NON-AC rooms
            pay_non_ac_single_double_double(choose)
          
        else:
            print("\nplease select a valid input")

# %%
# import random as r
#booking the hostel if room is not alloted
flag = True
while flag:
    chooseCampus = input("which hostel do you want to choose: (inside/outside)\nOr Enter exit to stop: \n").lower().strip()
    if chooseCampus == "exit":
        break
    #if student wish to choose the inside Hostel
    elif chooseCampus == "inside":
        isAC = input("Select the type AC/NON-AC: ").lower().strip()
        
        #AC and NON-AC selection
        AC_NONAC_selection_process(isAC)
            

        
    #if student wish to choose the ouside Hostel
    elif chooseCampus == "outside":
        isAC = input("Select the type AC/NON-AC: ").lower().strip()
        
        #AC and NON-AC selection
        AC_NONAC_selection_process(isAC)
# Out:
# which hostel do you want to choose: (inside/outside)
# Or Enter exit to stop:
#  inside
# Select the type AC/NON-AC:  ac
# AC Room and Respective Cost
#
# AC Single : ₹160000
# AC Double : ₹140000
#
# None
# Choose Single or Double AC rooms  single
# Enter your upi here:
#  dslfdf@d
# A payment link of ₹160000 has send to your number.
# Please pay that amount immediatly befor expire of link
#
# Thanks for the payment. Your room has been alloted
# which hostel do you want to choose: (inside/outside)
# Or Enter exit to stop:
#  exit

# %% [markdown]
# NOTE: Commented parts are only for practicing the doubts

# %%
# #file handling
# file = open("Day4Practice.txt", "w")
# # file.write("Pritam,Singar , 225")
# # file.write("Pritam, Singar, 225")
# file.write("*Pri*tam*,-Sin-gar-, 225")

# %%
# file = open("Day4Practice.txt", "r")
# file.readline().split(" ,")
# # print (value)

# %%
# file.close()
# print("File closed successfully")

# %% [markdown]
# List Comprehension
#
# TO FIX THE ABOVE ISSUES, WE USE FILE COMPRESSION

# %%
# file = open("Day4Practice.txt", "r")
# rawData = file.readline().split(",")
# cleanData = [items.strip(" -*") for items in rawData]   #by default, .strip() removes the white space from the beginning or end
# print(cleanData)
# print("Here it fails in middle")

# #it removes from the very left or very right of the data, but not from the middle, 
# #  to remove from the middle - we nee to use the remove() keyword

# %%
# for value in roomCosting:
#     # print(roomCosting[value])
#     print(value, ":", roomCosting[value])

# %% [markdown]
# CASE CONVERSION

# %%
# v = "AbcDeFG"

# %%
# print(v.lower())
# print(v.upper())

# %%
# print(v.title())

# %%
inOutCampus = input("which hostel do you want to choose: inside/outside").lower()

# %%
# print(inOutCampus)

# %% [markdown]
# #Make a demo practice of the hostel management system

# %%
# alloted_rooms = set()

# roomCosting = {"AC Single" : 160000,
#                   "AC Double" : 140000,
#                   "NON-AC Single" : 120000,
#                   "NON-AC Double" : 110000,
#                   "NON-AC Triple" : 900000}


# #booking the hostel if room is not alloted

# while True:
#     chooseCampus = input("which hostel do you want to choose: inside/outside: ").lower()
#     if chooseCampus == "inside":
#         isAC = input("Select the type AC/NON-AC: ").lower()
#         if isAC=="ac":
#             #printing the type and cost of ac rooms
#             print("\nAvailable AC Rooms:")
#             for room_type, cost in roomCosting.items():
#                 if "AC" in room_type and "NON-AC" not in room_type: # Added extra filter for safety
#                     print(f"{room_type} : ₹{cost}")

#         elif isAC == "non-ac":
#             print("\nAvailable NON-AC Rooms:")
#             for room_type, cost in roomCosting.items():
#                 if "NON-AC" in room_type:
#                     print(f"{room_type} : ₹{cost}")
#         else:
#             print("Invalid AC selection. Returning to main menu.")

#     elif chooseCampus == "outside":
#         print("Logic for outside campus goes here.")
#     else:
#         print("Invalid choice. Exiting program.")
#         break # Breaks the while loop

# %%
# choose = input("\nChoose Single or Double AC rooms ").lower().strip()
# print(choose)

# %%
flag = True
flag = "exit"

# %%
print(flag)
# Out:
# exit
